# %% [markdown]
# # Crawl Data Twitter > 2000 Tweets
# The crawling process was done using Tweet-Harvest. Written by Helmi Satria on  March 30th 2024.

# %%
#@title Twitter Auth Token

twitter_auth_token = '4710ac1ce44b8d9c2768cbc6820ec3a227201beb' # change this auth token

# %%
# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'NODE_MAJOR' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# v20.13.1

# %%
# Crawl Data

filename = 'horegNew.csv'
search_keyword = 'sound horeg since:2024-10-13 until:2024-11-13 lang:id'
limit = 450

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1854741631234457874  Sun Nov 10 23:55:03 +0000 2024               0
# 1    1855620089271431574  Sun Nov 10 23:27:27 +0000 2024               0
# 2    1855741599780843584  Sun Nov 10 22:49:03 +0000 2024               0
# 3    1855741599780843584  Sun Nov 10 22:37:30 +0000 2024               0
# 4    1855674291880407219  Sun Nov 10 21:24:24 +0000 2024               0
# ..                   ...                             ...             ...
# 251  1854558847249396017  Thu Nov 07 16:17:39 +0000 2024               0
# 252  1854032321978290412  Thu Nov 07 16:14:06 +0000 2024               0
# 253  1854532417496998242  Thu Nov 07 16:10:19 +0000 2024               0
# 254  1854350497840521548  Thu Nov 07 16:08:37 +0000 2024               0
# 255  1854544439076929628  Thu Nov 07 16:06:47 +0000 2024               0
#
#                                              full_text               id_str  \
# 0    @glavosl mau dengerin asing pake sound horeg p...  1855761115701248359
# 1    @meutiafaradilla Kenapa sih banyak orang bodoh...  1855754172571988171
# 2                    @boezun Info ngantemi sound horeg  1855744507473760748
# 3    Sebenernya visi misi dan tujuan ngeplay sound ...  1855741599780843584
# 4    @elcuomoo indonesia kudu maju heula ai sia pal...  1855723203378979252
# ..                                                 ...                  ...
# 251  kalo bohong mulu ntar dikirim sound horeg loh ...  1854558847249396017
# 252  @bacottetangga__ Emang di lombok ada sound horeg?  1854557950930833590
# 253  @peppermnd OP belum denger aja temenku kalau b...  1854556999167652002
# 254  @tanpawajah12 @jayapuraupdate Ya di jawa doank...  1854556571893928038
# 255  @Txtdaricupu Saya panggilkanko sound horeg. tu...  1854556112311435480
#
#     image_url in_reply_to_screen_name lang             location  quote_count  \
# 0         NaN                 glavosl   in             Rasha B.            0
# 1         NaN         meutiafaradilla   in                  NaN            0
# 2         NaN                  boezun   in                  NaN            0
# 3         NaN                     NaN   in               Bara's            0
# 4         NaN                elcuomoo   in                  NaN            0
# ..        ...                     ...  ...                  ...          ...
# 251       NaN                     NaN   in                  NaN            0
# 252       NaN         bacottetangga__   in                  NaN            0
# 253       NaN               peppermnd   in                  🐈‍⬛            0
# 254       NaN            tanpawajah12   in                  NaN            0
# 255       NaN              miko_stark   in  Makassar, Indonesia            0
#
#      reply_count  retweet_count  \
# 0              1              0
# 1              0              0
# 2              1              0
# 3              1              0
# 4              0              0
# ..           ...            ...
# 251            0              0
# 252            0              0
# 253            1              0
# 254            0              0
# 255            1              0
#
#                                              tweet_url          user_id_str  \
# 0    https://x.com/brokenmeowdies/status/1855761115...            130658158
# 1    https://x.com/kucingtelorasin/status/185575417...  1774066448295694337
# 2    https://x.com/yukkicart/status/185574450747376...  1492155550339330049
# 3      https://x.com/boezun/status/1855741599780843584  1304911296492527616
# 4    https://x.com/tepungberas33/status/18557232033...  1150223204285206528
# ..                                                 ...                  ...
# 251  https://x.com/arlllardht/status/18545588472493...  1526484573093515264
# 252  https://x.com/CodotHalusinasi/status/185455795...  1298581687358521349
# 253  https://x.com/vrisabbath/status/18545569991676...   769068957642924032
# 254  https://x.com/yamahazuzuki/status/185455657189...             68362329
# 255  https://x.com/miko_stark/status/18545561123114...  1633114297613144064
#
#             username
# 0     brokenmeowdies
# 1    kucingtelorasin
# 2          yukkicart
# 3             boezun
# 4      tepungberas33
# ..               ...
# 251       arlllardht
# 252  CodotHalusinasi
# 253       vrisabbath
# 254     yamahazuzuki
# 255       miko_stark
#
# [256 rows x 15 columns]

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 104.
